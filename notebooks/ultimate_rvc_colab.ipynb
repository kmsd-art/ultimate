# %% [markdown]
# <a href="https://colab.research.google.com/github/kmsd-art/ultimate/blob/main/notebooks/ultimate_rvc_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Colab for [Ultimate RVC](https://github.com/JackismyShephard/ultimate-rvc)
#
# This Colab notebook will **help** you if you don’t have a GPU or if your PC isn’t very powerful.
#
# Simply click `Runtime` in the top navigation bar and `Run all`. Wait for the output of the final cell to show the public gradio url and click on it.
#
# NOTE: If Ultimate RVC is running too slowly with the default sharing method (gradio), consider instead selecting "ngrok" as sharing method.
# This method requires supplying an access token, which you can find on [ngrok](https://ngrok.com/) after creating a personal account.
# The ngrok link output in the final cell will lead you to a new site which will redirect you to Ultimate RVC.

# %%
# @title 0: Initialize notebook
# %pip install ipython-autotime pyngrok
# %load_ext autotime

import codecs
import os
import time
from pathlib import Path
from urllib import request

import ipywidgets as widgets
from IPython.display import clear_output
from IPython.display import display as i_display
from pyngrok import ngrok

clear_output()
# Out:
# time: 55.4 ms (started: 2025-11-12 17:01:34 +00:00)

# %%
# @title 1: Clone repository
cloneing = codecs.decode(
    "uggcf://tvguho.pbz/WnpxvfzlFurcuneq/hygvzngr-eip.tvg",
    "rot_13",
)

# !git clone $cloneing HRVC
# %cd /content/HRVC
clear_output()
# Out:
# time: 1.32 s (started: 2025-11-12 17:01:34 +00:00)

# %%
# @title 2: Install dependencies

light = codecs.decode("uggcf://nfgeny.fu/hi/0.6.3/vafgnyy.fu", "rot_13")
inits = codecs.decode("./fep/hygvzngr_eip/pber/znva.cl", "rot_13")
prerelease = "--prerelease if-necessary-or-explicit"

# !apt install -y python3-dev unzip
# !curl -LsSf $light | sh

os.environ["URVC_CONSOLE_LOG_LEVEL"] = "WARNING"
# !uv run -q $prerelease $inits
# !uv add $prerelease matplotlib-inline==0.1.7
clear_output()
# Out:
# time: 3min 54s (started: 2025-11-12 17:01:35 +00:00)

# %%
# @title 3: Run Ultimate RVC
# @markdown  #### Choose a sharing method:

method = "gradio"  # @param ["gradio",  "ngrok", "cloudflared","localtunnel"]
ngrok_token = ""  # @param {type:"string"}
runpice = codecs.decode("./fep/hygvzngr_eip/jro/znva.cl", "rot_13")

if method == "gradio":
    # !uv run $prerelease $runpice --share
elif method == "ngrok":
    try:
        ngrok.set_auth_token(ngrok_token)
        ngrok.kill()
        tunnel = ngrok.connect(6969)
        print(f"Ngrok URL: {tunnel.public_url}")
        # !uv run $prerelease $runpice --listen-port 6969
    except Exception as e:  # noqa: BLE001
        print(f"Error starting ngrok: {e}")
elif method == "cloudflared":
    # !curl -LO https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
    # !dpkg -i cloudflared-linux-amd64.deb
    clear_output()
    # !rm -rf nohup.out
    # !nohup cloudflared tunnel --url localhost:6969 &
    clear_output()
    time.sleep(10)
    cloudflare_url = !grep -oE "https://[a-zA-Z0-9.-]+\.trycloudflare\.com" nohup.out
    print(f"URVC Public URL: {cloudflare_url}")
    # !uv run $prerelease $runpice --listen-port 6969
elif method == "localtunnel":
    # !npm install -g localtunnel &>/dev/null
    Path("url.txt").open("w", encoding="utf-8").close()
    # !lt --port 6969 >> url.txt 2>&1 &
    time.sleep(2)
    endpoint_ip = (
        request.urlopen("https://ipv4.icanhazip.com").read().decode("utf8").strip("\n")
    )
    tunnel_url = (
        Path("url.txt").read_text(encoding="utf-8").replace("your url is: ", "")
    )
    print(f"Share Link: {tunnel_url}")
    password_endpoint_widget = widgets.Text(
        value=endpoint_ip,
        description="Password IP:",
        disabled=True,
    )
    i_display(password_endpoint_widget)
    # !uv run $prerelease $runpice --listen-port 6969
# Out:
# Bytecode compiled 18316 files in 1.22s
# theme_schema%401.2.2.json: 14.7kB [00:00, 50.9MB/s]
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://546156910791511273.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# 100% 20/20 [01:04<00:00,  3.22s/it]
# [~] Extracting pitch features...
# 100% 625/625 [00:18<00:00, 33.20it/s]
# [~] Extracting audio embeddings...
# 100% 625/625 [00:11<00:00, 54.16it/s]
# /content/HRVC/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /content/HRVC/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# My model | epoch=1 | time=17:28:19 | speed=0:02:32 | best avg-gen-loss=5.506 (epoch 1)
# My model | epoch=2 | time=17:30:10 | speed=0:01:51 | best avg-gen-loss=5.332 (epoch 2)
# My model | epoch=3 | time=17:32:01 | speed=0:01:50 | best avg-gen-loss=5.190 (epoch 3)
# My model | epoch=4 | time=17:33:50 | speed=0:01:49 | best avg-gen-loss=5.104 (epoch 4)
# My model | epoch=5 | time=17:35:40 | speed=0:01:49 | best avg-gen-loss=4.990 (epoch 5)
# My model | epoch=6 | time=17:37:30 | speed=0:01:49 | best avg-gen-loss=4.990 (epoch 5)
# My model | epoch=7 | time=17:39:17 | speed=0:01:47 | best avg-gen-loss=4.990 (epoch 5)
# My model | epoch=8 | time=17:41:05 | speed=0:01:47 | best avg-gen-loss=4.963 (epoch 8)
# My model | epoch=9 | time=17:42:54 | speed=0:01:48 | best avg-gen-loss=4.963 (epoch 8)
# My model | epoch=10 | time=17:44:42 | speed=0:01:47 | best avg-gen-loss=4.963 (epoch 8)
# My model | epoch=11 | time=17:47:13 | speed=0:01:47 | best avg-gen-loss=4.963 (epoch 8)
# My model | epoch=12 | time=17:49:01 | speed=0:01:47 | best avg-gen-loss=4.963 (epoch 8)
# My model | epoch=13 | time=17:50:49 | speed=0:01:48 | best avg-gen-loss=4.963 (epoch 8)
# My model | epoch=14 | time=17:52:38 | speed=0:01:48 | best avg-gen-loss=4.963 (epoch 8)
# My model | epoch=15 | time=17:54:26 | speed=0:01:48 | best avg-gen-loss=4.963 (epoch 8)
# My model | epoch=16 | time=17:56:14 | speed=0:01:47 | best avg-gen-loss=4.963 (epoch 8)
# My model | epoch=17 | time=17:58:02 | speed=0:01:47 | best avg-gen-loss=4.963 (epoch 8)
# My model | epoch=18 | time=17:59:50 | speed=0:01:48 | best avg-gen-loss=4.963 (epoch 8)
# My model | epoch=19 | time=18:01:38 | speed=0:01:47 | best avg-gen-loss=4.940 (epoch 19)
# My model | epoch=20 | time=18:03:26 | speed=0:01:47 | best avg-gen-loss=4.872 (epoch 20)
# My model | epoch=21 | time=18:05:31 | speed=0:01:48 | best avg-gen-loss=4.872 (epoch 20)
# My model | epoch=22 | time=18:07:19 | speed=0:01:47 | best avg-gen-loss=4.872 (epoch 20)
# My model | epoch=23 | time=18:09:07 | speed=0:01:48 | best avg-gen-loss=4.872 (epoch 20)
# My model | epoch=24 | time=18:10:54 | speed=0:01:47 | best avg-gen-loss=4.872 (epoch 20)
# My model | epoch=25 | time=18:12:42 | speed=0:01:47 | best avg-gen-loss=4.872 (epoch 20)
# My model | epoch=26 | time=18:14:30 | speed=0:01:47 | best avg-gen-loss=4.872 (epoch 20)
# My model | epoch=27 | time=18:16:19 | speed=0:01:48 | best avg-gen-loss=4.872 (epoch 20)
# My model | epoch=28 | time=18:18:06 | speed=0:01:47 | best avg-gen-loss=4.872 (epoch 20)
# My model | epoch=29 | time=18:19:54 | speed=0:01:47 | best avg-gen-loss=4.872 (epoch 20)
# My model | epoch=30 | time=18:21:42 | speed=0:01:47 | best avg-gen-loss=4.872 (epoch 20)
# My model | epoch=31 | time=18:24:27 | speed=0:01:47 | best avg-gen-loss=4.872 (epoch 20)
# My model | epoch=32 | time=18:26:15 | speed=0:01:47 | best avg-gen-loss=4.872 (epoch 20)
# My model | epoch=33 | time=18:28:03 | speed=0:01:47 | best avg-gen-loss=4.872 (epoch 20)
# My model | epoch=34 | time=18:29:50 | speed=0:01:47 | best avg-gen-loss=4.872 (epoch 20)
# My model | epoch=35 | time=18:31:38 | speed=0:01:48 | best avg-gen-loss=4.872 (epoch 20)
# My model | epoch=36 | time=18:33:28 | speed=0:01:49 | best avg-gen-loss=4.825 (epoch 36)
# My model | epoch=37 | time=18:35:17 | speed=0:01:48 | best avg-gen-loss=4.825 (epoch 36)
# My model | epoch=38 | time=18:37:05 | speed=0:01:48 | best avg-gen-loss=4.825 (epoch 36)
# My model | epoch=39 | time=18:38:53 | speed=0:01:48 | best avg-gen-loss=4.825 (epoch 36)
# My model | epoch=40 | time=18:40:41 | speed=0:01:47 | best avg-gen-loss=4.825 (epoch 36)
# My model | epoch=41 | time=18:42:57 | speed=0:01:48 | best avg-gen-loss=4.825 (epoch 36)
# My model | epoch=42 | time=18:44:44 | speed=0:01:47 | best avg-gen-loss=4.825 (epoch 36)
# My model | epoch=43 | time=18:46:32 | speed=0:01:47 | best avg-gen-loss=4.802 (epoch 43)
# My model | epoch=44 | time=18:48:20 | speed=0:01:47 | best avg-gen-loss=4.802 (epoch 43)
# My model | epoch=45 | time=18:50:08 | speed=0:01:47 | best avg-gen-loss=4.802 (epoch 43)
# My model | epoch=46 | time=18:51:56 | speed=0:01:47 | best avg-gen-loss=4.802 (epoch 43)
# My model | epoch=47 | time=18:53:44 | speed=0:01:47 | best avg-gen-loss=4.802 (epoch 43)
# My model | epoch=48 | time=18:55:31 | speed=0:01:47 | best avg-gen-loss=4.802 (epoch 43)
# My model | epoch=49 | time=18:57:20 | speed=0:01:48 | best avg-gen-loss=4.802 (epoch 43)
# My model | epoch=50 | time=18:59:09 | speed=0:01:48 | best avg-gen-loss=4.802 (epoch 43)
# My model | epoch=51 | time=19:01:39 | speed=0:01:48 | best avg-gen-loss=4.802 (epoch 43)
# My model | epoch=52 | time=19:03:27 | speed=0:01:47 | best avg-gen-loss=4.802 (epoch 43)
# My model | epoch=53 | time=19:05:15 | speed=0:01:47 | best avg-gen-loss=4.802 (epoch 43)
# My model | epoch=54 | time=19:07:02 | speed=0:01:47 | best avg-gen-loss=4.802 (epoch 43)
# My model | epoch=55 | time=19:08:50 | speed=0:01:47 | best avg-gen-loss=4.802 (epoch 43)
# My model | epoch=56 | time=19:10:39 | speed=0:01:48 | best avg-gen-loss=4.802 (epoch 43)
# My model | epoch=57 | time=19:12:27 | speed=0:01:48 | best avg-gen-loss=4.767 (epoch 57)
# My model | epoch=58 | time=19:14:15 | speed=0:01:47 | best avg-gen-loss=4.767 (epoch 57)
# My model | epoch=59 | time=19:16:03 | speed=0:01:48 | best avg-gen-loss=4.767 (epoch 57)
# My model | epoch=60 | time=19:17:51 | speed=0:01:48 | best avg-gen-loss=4.767 (epoch 57)
# My model | epoch=61 | time=19:20:10 | speed=0:01:47 | best avg-gen-loss=4.767 (epoch 57)
# My model | epoch=62 | time=19:21:58 | speed=0:01:48 | best avg-gen-loss=4.767 (epoch 57)
# My model | epoch=63 | time=19:23:46 | speed=0:01:47 | best avg-gen-loss=4.767 (epoch 57)
# My model | epoch=64 | time=19:25:34 | speed=0:01:48 | best avg-gen-loss=4.767 (epoch 57)
# My model | epoch=65 | time=19:27:22 | speed=0:01:47 | best avg-gen-loss=4.767 (epoch 57)
# My model | epoch=66 | time=19:29:11 | speed=0:01:48 | best avg-gen-loss=4.767 (epoch 57)
# My model | epoch=67 | time=19:30:58 | speed=0:01:47 | best avg-gen-loss=4.767 (epoch 57)
# My model | epoch=68 | time=19:32:47 | speed=0:01:48 | best avg-gen-loss=4.767 (epoch 57)
# My model | epoch=69 | time=19:34:36 | speed=0:01:49 | best avg-gen-loss=4.767 (epoch 57)
# My model | epoch=70 | time=19:36:24 | speed=0:01:48 | best avg-gen-loss=4.767 (epoch 57)
# My model | epoch=71 | time=19:38:48 | speed=0:01:47 | best avg-gen-loss=4.767 (epoch 57)
# My model | epoch=72 | time=19:40:36 | speed=0:01:47 | best avg-gen-loss=4.767 (epoch 57)
# My model | epoch=73 | time=19:42:24 | speed=0:01:48 | best avg-gen-loss=4.767 (epoch 57)
# My model | epoch=74 | time=19:44:11 | speed=0:01:47 | best avg-gen-loss=4.767 (epoch 57)
# My model | epoch=75 | time=19:45:59 | speed=0:01:47 | best avg-gen-loss=4.751 (epoch 75)
# My model | epoch=76 | time=19:47:48 | speed=0:01:48 | best avg-gen-loss=4.751 (epoch 75)
# My model | epoch=77 | time=19:49:38 | speed=0:01:49 | best avg-gen-loss=4.751 (epoch 75)
# My model | epoch=78 | time=19:51:26 | speed=0:01:47 | best avg-gen-loss=4.751 (epoch 75)
# My model | epoch=79 | time=19:53:14 | speed=0:01:48 | best avg-gen-loss=4.751 (epoch 75)
# My model | epoch=80 | time=19:55:02 | speed=0:01:47 | best avg-gen-loss=4.751 (epoch 75)
# My model | epoch=81 | time=19:57:18 | speed=0:01:48 | best avg-gen-loss=4.718 (epoch 81)
# My model | epoch=82 | time=19:59:06 | speed=0:01:47 | best avg-gen-loss=4.718 (epoch 81)
# My model | epoch=83 | time=20:00:54 | speed=0:01:47 | best avg-gen-loss=4.718 (epoch 81)
# My model | epoch=84 | time=20:02:41 | speed=0:01:47 | best avg-gen-loss=4.718 (epoch 81)
# My model | epoch=85 | time=20:04:29 | speed=0:01:47 | best avg-gen-loss=4.718 (epoch 81)
# My model | epoch=86 | time=20:06:17 | speed=0:01:47 | best avg-gen-loss=4.718 (epoch 81)
# My model | epoch=87 | time=20:08:05 | speed=0:01:48 | best avg-gen-loss=4.718 (epoch 81)
# My model | epoch=88 | time=20:09:53 | speed=0:01:47 | best avg-gen-loss=4.718 (epoch 81)
# My model | epoch=89 | time=20:11:41 | speed=0:01:48 | best avg-gen-loss=4.718 (epoch 81)
# My model | epoch=90 | time=20:13:29 | speed=0:01:48 | best avg-gen-loss=4.718 (epoch 81)
# My model | epoch=91 | time=20:16:15 | speed=0:01:47 | best avg-gen-loss=4.718 (epoch 81)
# My model | epoch=92 | time=20:18:03 | speed=0:01:47 | best avg-gen-loss=4.718 (epoch 81)
# My model | epoch=93 | time=20:19:52 | speed=0:01:49 | best avg-gen-loss=4.718 (epoch 81)
# My model | epoch=94 | time=20:21:41 | speed=0:01:48 | best avg-gen-loss=4.718 (epoch 81)
# My model | epoch=95 | time=20:23:28 | speed=0:01:47 | best avg-gen-loss=4.718 (epoch 81)
# My model | epoch=96 | time=20:25:16 | speed=0:01:47 | best avg-gen-loss=4.718 (epoch 81)
# My model | epoch=97 | time=20:27:04 | speed=0:01:47 | best avg-gen-loss=4.718 (epoch 81)
# My model | epoch=98 | time=20:28:52 | speed=0:01:48 | best avg-gen-loss=4.718 (epoch 81)
# My model | epoch=99 | time=20:30:40 | speed=0:01:47 | best avg-gen-loss=4.718 (epoch 81)
# My model | epoch=100 | time=20:32:27 | speed=0:01:47 | best avg-gen-loss=4.718 (epoch 81)
# My model | epoch=101 | time=20:35:06 | speed=0:01:47 | best avg-gen-loss=4.718 (epoch 81)
# My model | epoch=102 | time=20:36:55 | speed=0:01:48 | best avg-gen-loss=4.718 (epoch 81)
# My model | epoch=103 | time=20:38:42 | speed=0:01:47 | best avg-gen-loss=4.712 (epoch 103)
# My model | epoch=104 | time=20:40:31 | speed=0:01:47 | best avg-gen-loss=4.712 (epoch 103)
# My model | epoch=105 | time=20:42:18 | speed=0:01:47 | best avg-gen-loss=4.712 (epoch 103)
# My model | epoch=106 | time=20:44:07 | speed=0:01:48 | best avg-gen-loss=4.712 (epoch 103)
# My model | epoch=107 | time=20:45:54 | speed=0:01:47 | best avg-gen-loss=4.712 (epoch 103)
# My model | epoch=108 | time=20:47:43 | speed=0:01:48 | best avg-gen-loss=4.712 (epoch 103)
# My model | epoch=109 | time=20:49:31 | speed=0:01:47 | best avg-gen-loss=4.712 (epoch 103)
# My model | epoch=110 | time=20:51:19 | speed=0:01:48 | best avg-gen-loss=4.712 (epoch 103)
# My model | epoch=111 | time=20:53:56 | speed=0:01:47 | best avg-gen-loss=4.712 (epoch 103)
# My model | epoch=112 | time=20:55:44 | speed=0:01:47 | best avg-gen-loss=4.672 (epoch 112)
# My model | epoch=113 | time=20:57:32 | speed=0:01:48 | best avg-gen-loss=4.672 (epoch 112)
# My model | epoch=114 | time=20:59:20 | speed=0:01:48 | best avg-gen-loss=4.651 (epoch 114)
# My model | epoch=115 | time=21:01:08 | speed=0:01:47 | best avg-gen-loss=4.651 (epoch 114)
# My model | epoch=116 | time=21:02:56 | speed=0:01:47 | best avg-gen-loss=4.651 (epoch 114)
# My model | epoch=117 | time=21:04:44 | speed=0:01:47 | best avg-gen-loss=4.651 (epoch 114)
# My model | epoch=118 | time=21:06:32 | speed=0:01:47 | best avg-gen-loss=4.651 (epoch 114)
# My model | epoch=119 | time=21:08:19 | speed=0:01:47 | best avg-gen-loss=4.600 (epoch 119)
# My model | epoch=120 | time=21:10:07 | speed=0:01:47 | best avg-gen-loss=4.600 (epoch 119)
# My model | epoch=121 | time=21:12:25 | speed=0:01:48 | best avg-gen-loss=4.600 (epoch 119)
# My model | epoch=122 | time=21:14:13 | speed=0:01:48 | best avg-gen-loss=4.600 (epoch 119)
# My model | epoch=123 | time=21:16:02 | speed=0:01:48 | best avg-gen-loss=4.600 (epoch 119)
# My model | epoch=124 | time=21:17:49 | speed=0:01:47 | best avg-gen-loss=4.600 (epoch 119)
# My model | epoch=125 | time=21:19:37 | speed=0:01:48 | best avg-gen-loss=4.600 (epoch 119)
# My model | epoch=126 | time=21:21:26 | speed=0:01:48 | best avg-gen-loss=4.600 (epoch 119)
# My model | epoch=127 | time=21:23:15 | speed=0:01:48 | best avg-gen-loss=4.600 (epoch 119)
# My model | epoch=128 | time=21:25:03 | speed=0:01:48 | best avg-gen-loss=4.600 (epoch 119)
# My model | epoch=129 | time=21:26:51 | speed=0:01:48 | best avg-gen-loss=4.600 (epoch 119)
# My model | epoch=130 | time=21:28:40 | speed=0:01:49 | best avg-gen-loss=4.600 (epoch 119)
# My model | epoch=131 | time=21:30:44 | speed=0:01:48 | best avg-gen-loss=4.600 (epoch 119)
# My model | epoch=132 | time=21:32:32 | speed=0:01:47 | best avg-gen-loss=4.600 (epoch 119)
# My model | epoch=133 | time=21:34:20 | speed=0:01:47 | best avg-gen-loss=4.600 (epoch 119)
# My model | epoch=134 | time=21:36:07 | speed=0:01:47 | best avg-gen-loss=4.600 (epoch 119)
# My model | epoch=135 | time=21:37:55 | speed=0:01:47 | best avg-gen-loss=4.600 (epoch 119)
# My model | epoch=136 | time=21:39:43 | speed=0:01:47 | best avg-gen-loss=4.600 (epoch 119)
# My model | epoch=137 | time=21:41:31 | speed=0:01:47 | best avg-gen-loss=4.600 (epoch 119)
# My model | epoch=138 | time=21:43:19 | speed=0:01:48 | best avg-gen-loss=4.600 (epoch 119)
# My model | epoch=139 | time=21:45:07 | speed=0:01:47 | best avg-gen-loss=4.600 (epoch 119)
# My model | epoch=140 | time=21:46:55 | speed=0:01:47 | best avg-gen-loss=4.600 (epoch 119)
# My model | epoch=141 | time=21:49:24 | speed=0:01:48 | best avg-gen-loss=4.600 (epoch 119)
# My model | epoch=142 | time=21:51:13 | speed=0:01:48 | best avg-gen-loss=4.600 (epoch 119)
# My model | epoch=143 | time=21:53:02 | speed=0:01:48 | best avg-gen-loss=4.600 (epoch 119)
# My model | epoch=144 | time=21:54:50 | speed=0:01:48 | best avg-gen-loss=4.600 (epoch 119)
# My model | epoch=145 | time=21:56:39 | speed=0:01:48 | best avg-gen-loss=4.600 (epoch 119)
# My model | epoch=146 | time=21:58:27 | speed=0:01:48 | best avg-gen-loss=4.600 (epoch 119)
# My model | epoch=147 | time=22:00:14 | speed=0:01:47 | best avg-gen-loss=4.600 (epoch 119)
# My model | epoch=148 | time=22:02:03 | speed=0:01:48 | best avg-gen-loss=4.600 (epoch 119)
#  35% 28/80 [00:38<01:09,  1.33s/it]
